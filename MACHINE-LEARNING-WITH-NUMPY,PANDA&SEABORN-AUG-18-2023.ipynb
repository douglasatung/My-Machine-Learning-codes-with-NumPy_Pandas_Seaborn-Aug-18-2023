# %% [markdown]
# # Importing Libaries

# %%
#PANDAS CLASS ON DATA HANDLING USING A DATA NAME House_price
import seaborn as sns
import pandas as pd
import numpy as np
data = pd.read_csv('House_price.csv')

# %%
#We are exploring the use of head(), tail(), info() and describe()
data.head()
#This give us the display of our Dataframe
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
#Data tail gives us the display of the last row of the Dataframe
data.tail()
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 501   2.76   2.06      19.0       9.67      NO       9.348      12.1792
# 502   2.46   2.14      19.0       9.08     YES       6.612      13.1648
# 503   2.29   1.98      19.0       5.64      NO       5.478      12.1912
# 504   2.40   2.31      19.0       6.48     YES       7.940      15.1760
# 505   2.64   2.42      19.0       7.88     YES      10.280      10.1520
#
#           waterbody  rainfall bus_ter     parks
# ...

# %%
#Data info gives us the information about the Dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    351 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
#Data description gives us the summary statistics of the Dataframe
data.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %% [markdown]
# ## Accessing a single column

# %%
#Accessing a single column
#The column with a single column do not carry double [[--]] but a single [ -]
column = data['crime_rate']

column
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: crime_rate, Length: 506, dtype: float64

# %%
#Accessing multiple numbers of culumns by name
#Access multiple number of columns, the list must be [[ ]]
columns = data[['price', 'resid_area', 'room_num', 'age', 'dist2', 'dist4', 'n_hos_beds']] 
columns.head()
# Out:
#    price  resid_area  room_num   age  dist2  dist4  n_hos_beds
# 0   24.0       32.31     6.575  65.2   3.81   4.01       5.480
# 1   21.6       37.07     6.421  78.9   4.70   5.06       7.332
# 2   34.7       37.07     7.185  61.1   4.86   4.97       7.394
# 3   33.4       32.18     6.998  45.8   5.93   5.96       9.268
# 4   36.2       32.18     7.147  54.2   5.86   5.86       8.824

# %% [markdown]
# # HANDLING MISSING DATA

# %%
'''#HANDLING MISSING DATA
Missing data is a prevalent issue in the real-world dataset. 
Pandas deem it fit to handle missing values, such as dropna() and fillna() 
'''
#To drop a row with missing value we code
data_without_missing = data.dropna()

#To fill missing values with a specific value we enter
data_filled = data.fillna(0)

#To forward-fill missing values we write that
data_ffill = data.ffill()

#Backward-fill missing values
data_bfill = data.bfill()

data_without_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 343 entries, 0 to 502
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        343 non-null    float64
#  1   crime_rate   343 non-null    float64
#  2   resid_area   343 non-null    float64
#  3   air_qual     343 non-null    float64
#  4   room_num     343 non-null    float64
#  5   age          343 non-null    float64
#  6   dist1        343 non-null    float64
#  7   dist2        343 non-null    float64
#  8   dist3        343 non-null    float64
#  9   dist4        343 non-null    float64
#  10  teachers     343 non-null    float64
#  11  poor_prop    343 non-null    float64
#  12  airport      343 non-null    object
#  13  n_hos_beds   343 non-null    float64
#  14  n_hot_rooms  343 non-null    float64
#  15  waterbody    343 non-null    object
#  16  rainfall     343 non-null    int64
#  17  bus_ter      343 non-null    object
# ...

# %%
sns.scatterplot(x="resid_area", y="age", data=data)
# Out:
# <Axes: xlabel='resid_area', ylabel='age'>

# %%
data.crime_rate
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: crime_rate, Length: 506, dtype: float64

# %%
np.log(data.crime_rate).describe()
# Out:
# count    506.000000
# mean      -0.780436
# std        2.162050
# min       -5.064036
# 25%       -2.500488
# 50%       -1.360641
# 75%        1.302119
# max        4.488369
# Name: crime_rate, dtype: float64

# %%
np.sqrt(data.crime_rate).describe()
# Out:
# count    506.000000
# mean       1.229439
# std        1.451263
# min        0.079498
# 25%        0.286435
# 50%        0.506461
# 75%        1.917572
# max        9.432720
# Name: crime_rate, dtype: float64
